# %%
# external imports
import music21 as m21
import ast
import os

# %%
# reload cell
from src.midi import *
from src.train import *
import sys, importlib
importlib.reload(sys.modules['src.midi'])
importlib.reload(sys.modules['src.train'])
# Out:
# <module 'src.train' from 'C:\\Users\\AC56874\\Documents\\GitHub\\Pyotr\\src\\train.py'>

# %% [markdown]
# # Encoding and Read-in

# %%
# Read in all of the midi files
path = './data/sample'
mdl = gen_md_from_path(path, by_measure=False, verbose=False)
mdm = gen_md_from_path(path, by_measure=True, verbose=False)

# %%
# Encode them (as entire piece)
me = MidiEncoder()
mdl_enc = {}
for piece in mdl:
    mdl_enc[piece] = me.Encode(mdl[piece].flat, 'pitch_position_duration_strings')

# %%
# Encode them (by measure)
me = MidiEncoder()
mdm_enc = {}
for piece in mdm:
    mdm_enc[piece] = {}
    for i, m in enumerate(mdm[piece]):
        mdm_enc[piece][i] = me.Encode(m, 'pitch_position_duration_strings')

# %%
# Vocab Sizes
un = []; count = 0;
for piece in mdl_enc:
    for token in mdl_enc[piece]:
        count += 1
        if token not in un:
            un.append(token)
print(f"{len(un)} / {count}")
# Out:
# 12258 / 14921

# %%
# Vocab Sizes
un = []; count = 0;
for piece in mdm_enc:
    for meas in mdm_enc[piece]:
        for token in mdm_enc[piece][meas]:
            count += 1
            if token not in un:
                un.append(token)
print(f"{len(un)} / {count}")
# Out:
# 2762 / 14921

# %% [markdown]
# # Pre-processing

# %%
tsg = TrainingSetBuilder(mdm_enc, by_measure=True)
tsg.Build('next_note')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-01c4423ed401> in <module>
#       1 tsg = TrainingSetBuilder(mdm_enc, by_measure=True)
# ----> 2 tsg.Build('next_note')
#
# ~\Documents\GitHub\Pyotr\src\train.py in Build(self, build_type)
#      30         """
#      31         if build_type in self.build_map.keys():
# ---> 32             return self.build_map[build_type]()
#      33         else:
#      34             raise ValueError("Build Type not Found, see TrainingSetBuilder().build_map for supported types.")
#
# ~\Documents\GitHub\Pyotr\src\train.py in build_next_note(self)
#      52             for i in range(0, num_samples):
#      53                 df.loc[i+offset, X_cols] = self.mdict_enc_f[piece][i:i+self.num_notes]
# ---> 54                 df.loc[i+offset, y_col] = self.mdict_enc_f[piece][i+self.num_notes+1]
#      55             offset += num_samples
#      56
#
# IndexError: list index out of range

# %%
tsg.mdict_enc_f
# Out:
# ['C4:0.0:2.0',
#  'E4:0.25:1.75',
#  'G4:0.5:0.25',
#  'C5:0.75:0.25',
#  'E5:1.0:0.25',
#  'G4:1.25:0.25',
#  'C5:1.5:0.25',
#  'E5:1.75:0.25',
#  'C4:2.0:2.0',
#  'E4:2.25:1.75',
#  'G4:2.5:0.25',
#  'C5:2.75:0.25',
#  'E5:3.0:0.25',
#  'G4:3.25:0.25',
#  'C5:3.5:0.25',
#  'E5:3.75:0.25',
#  'C4:0.0:2.0',
#  'D4:0.25:1.75',
#  'A4:0.5:0.25',
#  'D5:0.75:0.25',
#  'F5:1.0:0.25',
#  'A4:1.25:0.25',
#  'D5:1.5:0.25',
#  'F5:1.75:0.25',
#  'C4:2.0:2.0',
#  'D4:2.25:1.75',
#  'A4:2.5:0.25',
#  'D5:2.75:0.25',
#  'F5:3.0:0.25',
#  'A4:3.25:0.25',
#  'D5:3.5:0.25',
#  'F5:3.75:0.25',
#  'B3:0.0:2.0',
#  'D4:0.25:1.75',
#  'G4:0.5:0.25',
#  'D5:0.75:0.25',
#  'F5:1.0:0.25',
#  'G4:1.25:0.25',
#  'D5:1.5:0.25',
#  'F5:1.75:0.25',
#  'B3:2.0:2.0',
#  'D4:2.25:1.75',
#  'G4:2.5:0.25',
#  'D5:2.75:0.25',
#  'F5:3.0:0.25',
#  'G4:3.25:0.25',
#  'D5:3.5:0.25',
#  'F5:3.75:0.25',
#  'C4:0.0:2.0',
#  'E4:0.25:1.75',
#  'G4:0.5:0.25',
#  'C5:0.75:0.25',
#  'E5:1.0:0.25',
#  'G4:1.25:0.25',
#  'C5:1.5:0.25',
#  'E5:1.75:0.25',
#  'C4:2.0:2.0',
#  'E4:2.25:1.75',
#  'G4:2.5:0.25',
#  'C5:2.75:0.25',
#  'E5:3.0:0.25',
#  'G4:3.25:0.25',
#  'C5:3.5:0.25',
#  'E5:3.75:0.25',
#  'C4:0.0:2.0',
#  'E4:0.25:1.75',
#  'A4:0.5:0.25',
#  'E5:0.75:0.25',
#  'A5:1.0:0.25',
#  'A4:1.25:0.25',
#  'E5:1.5:0.25',
#  'A5:1.75:0.25',
#  'C4:2.0:2.0',
#  'E4:2.25:1.75',
#  'A4:2.5:0.25',
#  'E5:2.75:0.25',
#  'A5:3.0:0.25',
#  'A4:3.25:0.25',
#  'E5:3.5:0.25',
#  'A5:3.75:0.25',
#  'C4:0.0:2.0',
#  'D4:0.25:1.75',
#  'F#4:0.5:0.25',
#  'A4:0.75:0.25',
#  'D5:1.0:0.25',
#  'F#4:1.25:0.25',
#  'A4:1.5:0.25',
#  'D5:1.75:0.25',
#  'C4:2.0:2.0',
#  'D4:2.25:1.75',
#  'F#4:2.5:0.25',
#  'A4:2.75:0.25',
#  'D5:3.0:0.25',
#  'F#4:3.25:0.25',
#  'A4:3.5:0.25',
#  'D5:3.75:0.25',
#  'B3:0.0:2.0',
#  'D4:0.25:1.75',
#  'G4:0.5:0.25',
#  'D5:0.75:0.25',
#  'G5:1.0:0.25',
#  'G4:1.25:0.25',
#  'D5:1.5:0.25',
#  'G5:1.75:0.25',
#  'B3:2.0:2.0',
#  'D4:2.25:1.75',
#  'G4:2.5:0.25',
#  'D5:2.75:0.25',
#  'G5:3.0:0.25',
#  'G4:3.25:0.25',
#  'D5:3.5:0.25',
#  'G5:3.75:0.25',
#  'B3:0.0:2.0',
#  'C4:0.25:1.75',
#  'E4:0.5:0.25',
#  'G4:0.75:0.25',
#  'C5:1.0:0.25',
#  'E4:1.25:0.25',
#  'G4:1.5:0.25',
#  'C5:1.75:0.25',
#  'B3:2.0:2.0',
#  'C4:2.25:1.75',
#  'E4:2.5:0.25',
#  'G4:2.75:0.25',
#  'C5:3.0:0.25',
#  'E4:3.25:0.25',
#  'G4:3.5:0.25',
#  'C5:3.75:0.25',
#  'A3:0.0:2.0',
#  'C4:0.25:1.75',
#  'E4:0.5:0.25',
#  'G4:0.75:0.25',
#  'C5:1.0:0.25',
#  'E4:1.25:0.25',
#  'G4:1.5:0.25',
#  'C5:1.75:0.25',
#  'A3:2.0:2.0',
#  'C4:2.25:1.75',
#  'E4:2.5:0.25',
#  'G4:2.75:0.25',
#  'C5:3.0:0.25',
#  'E4:3.25:0.25',
#  'G4:3.5:0.25',
#  'C5:3.75:0.25',
#  'D3:0.0:2.0',
#  'A3:0.25:1.75',
#  'D4:0.5:0.25',
#  'F#4:0.75:0.25',
#  'C5:1.0:0.25',
#  'D4:1.25:0.25',
#  'F#4:1.5:0.25',
#  'C5:1.75:0.25',
#  'D3:2.0:2.0',
#  'A3:2.25:1.75',
#  'D4:2.5:0.25',
#  'F#4:2.75:0.25',
#  'C5:3.0:0.25',
#  'D4:3.25:0.25',
#  'F#4:3.5:0.25',
#  'C5:3.75:0.25',
#  'G3:0.0:2.0',
#  'B3:0.25:1.75',
#  'D4:0.5:0.25',
#  'G4:0.75:0.25',
#  'B4:1.0:0.25',
#  'D4:1.25:0.25',
#  'G4:1.5:0.25',
#  'B4:1.75:0.25',
#  'G3:2.0:2.0',
#  'B3:2.25:1.75',
#  'D4:2.5:0.25',
#  'G4:2.75:0.25',
#  'B4:3.0:0.25',
#  'D4:3.25:0.25',
#  'G4:3.5:0.25',
#  'B4:3.75:0.25',
#  'G3:0.0:2.0',
#  'B-3:0.25:1.75',
#  'E4:0.5:0.25',
#  'G4:0.75:0.25',
#  'C#5:1.0:0.25',
#  'E4:1.25:0.25',
#  'G4:1.5:0.25',
#  'C#5:1.75:0.25',
#  'G3:2.0:2.0',
#  'B-3:2.25:1.75',
#  'E4:2.5:0.25',
#  'G4:2.75:0.25',
#  'C#5:3.0:0.25',
#  'E4:3.25:0.25',
#  'G4:3.5:0.25',
#  'C#5:3.75:0.25',
#  'F3:0.0:2.0',
#  'A3:0.25:1.75',
#  'D4:0.5:0.25',
#  'A4:0.75:0.25',
#  'D5:1.0:0.25',
#  'D4:1.25:0.25',
#  'A4:1.5:0.25',
#  'D5:1.75:0.25',
#  'F3:2.0:2.0',
#  'A3:2.25:1.75',
#  'D4:2.5:0.25',
#  'A4:2.75:0.25',
#  'D5:3.0:0.25',
#  'D4:3.25:0.25',
#  'A4:3.5:0.25',
#  'D5:3.75:0.25',
#  'F3:0.0:2.0',
#  'G#3:0.25:1.75',
#  'D4:0.5:0.25',
#  'F4:0.75:0.25',
#  'B4:1.0:0.25',
#  'D4:1.25:0.25',
#  'F4:1.5:0.25',
#  'B4:1.75:0.25',
#  'F3:2.0:2.0',
#  'G#3:2.25:1.75',
#  'D4:2.5:0.25',
#  'F4:2.75:0.25',
#  'B4:3.0:0.25',
#  'D4:3.25:0.25',
#  'F4:3.5:0.25',
#  'B4:3.75:0.25',
#  'E3:0.0:2.0',
#  'G3:0.25:1.75',
#  'C4:0.5:0.25',
#  'G4:0.75:0.25',
#  'C5:1.0:0.25',
#  'C4:1.25:0.25',
#  'G4:1.5:0.25',
#  'C5:1.75:0.25',
#  'E3:2.0:2.0',
#  'G3:2.25:1.75',
#  'C4:2.5:0.25',
#  'G4:2.75:0.25',
#  'C5:3.0:0.25',
#  'C4:3.25:0.25',
#  'G4:3.5:0.25',
#  'C5:3.75:0.25',
#  'E3:0.0:2.0',
#  'F3:0.25:1.75',
#  'A3:0.5:0.25',
#  'C4:0.75:0.25',
#  'F4:1.0:0.25',
#  'A3:1.25:0.25',
#  'C4:1.5:0.25',
#  'F4:1.75:0.25',
#  'E3:2.0:2.0',
#  'F3:2.25:1.75',
#  'A3:2.5:0.25',
#  'C4:2.75:0.25',
#  'F4:3.0:0.25',
#  'A3:3.25:0.25',
#  'C4:3.5:0.25',
#  'F4:3.75:0.25',
#  'D3:0.0:2.0',
#  'F3:0.25:1.75',
#  'A3:0.5:0.25',
#  'C4:0.75:0.25',
#  'F4:1.0:0.25',
#  'A3:1.25:0.25',
#  'C4:1.5:0.25',
#  'F4:1.75:0.25',
#  'D3:2.0:2.0',
#  'F3:2.25:1.75',
#  'A3:2.5:0.25',
#  'C4:2.75:0.25',
#  'F4:3.0:0.25',
#  'A3:3.25:0.25',
#  'C4:3.5:0.25',
#  'F4:3.75:0.25',
#  'G2:0.0:2.0',
#  'D3:0.25:1.75',
#  'G3:0.5:0.25',
#  'B3:0.75:0.25',
#  'F4:1.0:0.25',
#  'G3:1.25:0.25',
#  'B3:1.5:0.25',
#  'F4:1.75:0.25',
#  'G2:2.0:2.0',
#  'D3:2.25:1.75',
#  'G3:2.5:0.25',
#  'B3:2.75:0.25',
#  'F4:3.0:0.25',
#  'G3:3.25:0.25',
#  'B3:3.5:0.25',
#  'F4:3.75:0.25',
#  'C3:0.0:2.0',
#  'E3:0.25:1.75',
#  'G3:0.5:0.25',
#  'C4:0.75:0.25',
#  'E4:1.0:0.25',
#  'G3:1.25:0.25',
#  'C4:1.5:0.25',
#  'E4:1.75:0.25',
#  'C3:2.0:2.0',
#  'E3:2.25:1.75',
#  'G3:2.5:0.25',
#  'C4:2.75:0.25',
#  'E4:3.0:0.25',
#  'G3:3.25:0.25',
#  'C4:3.5:0.25',
#  'E4:3.75:0.25',
#  'C3:0.0:2.0',
#  'G3:0.25:1.75',
#  'B-3:0.5:0.25',
#  'C4:0.75:0.25',
#  'E4:1.0:0.25',
#  'B-3:1.25:0.25',
#  'C4:1.5:0.25',
#  'E4:1.75:0.25',
#  'C3:2.0:2.0',
#  'G3:2.25:1.75',
#  'B-3:2.5:0.25',
#  'C4:2.75:0.25',
#  'E4:3.0:0.25',
#  'B-3:3.25:0.25',
#  'C4:3.5:0.25',
#  'E4:3.75:0.25',
#  'F2:0.0:2.0',
#  'F3:0.25:1.75',
#  'A3:0.5:0.25',
#  'C4:0.75:0.25',
#  'E4:1.0:0.25',
#  'A3:1.25:0.25',
#  'C4:1.5:0.25',
#  'E4:1.75:0.25',
#  'F2:2.0:2.0',
#  'F3:2.25:1.75',
#  'A3:2.5:0.25',
#  'C4:2.75:0.25',
#  'E4:3.0:0.25',
#  'A3:3.25:0.25',
#  'C4:3.5:0.25',
#  'E4:3.75:0.25',
#  'F#2:0.0:2.0',
#  'C3:0.25:1.75',
#  'A3:0.5:0.25',
#  'C4:0.75:0.25',
#  'E-4:1.0:0.25',
#  'A3:1.25:0.25',
#  'C4:1.5:0.25',
#  'E-4:1.75:0.25',
#  'F#2:2.0:2.0',
#  'C3:2.25:1.75',
#  'A3:2.5:0.25',
#  'C4:2.75:0.25',
#  'E-4:3.0:0.25',
#  'A3:3.25:0.25',
#  'C4:3.5:0.25',
#  'E-4:3.75:0.25',
#  'G#2:0.0:2.0',
#  'F3:0.25:1.75',
#  'B3:0.5:0.25',
#  'C4:0.75:0.25',
#  'D4:1.0:0.25',
#  'B3:1.25:0.25',
#  'C4:1.5:0.25',
#  'D4:1.75:0.25',
#  'G#2:2.0:2.0',
#  'F3:2.25:1.75',
#  'B3:2.5:0.25',
#  'C4:2.75:0.25',
#  'D4:3.0:0.25',
#  'B3:3.25:0.25',
#  'C4:3.5:0.25',
#  'D4:3.75:0.25',
#  'G2:0.0:2.0',
#  'F3:0.25:1.75',
#  'G3:0.5:0.25',
#  'B3:0.75:0.25',
#  'D4:1.0:0.25',
#  'G3:1.25:0.25',
#  'B3:1.5:0.25',
#  'D4:1.75:0.25',
#  'G2:2.0:2.0',
#  'F3:2.25:1.75',
#  'G3:2.5:0.25',
#  'B3:2.75:0.25',
#  'D4:3.0:0.25',
#  'G3:3.25:0.25',
#  'B3:3.5:0.25',
#  'D4:3.75:0.25',
#  'G2:0.0:2.0',
#  'E3:0.25:1.75',
#  'G3:0.5:0.25',
#  'C4:0.75:0.25',
#  'E4:1.0:0.25',
#  'G3:1.25:0.25',
#  'C4:1.5:0.25',
#  'E4:1.75:0.25',
#  'G2:2.0:2.0',
#  'E3:2.25:1.75',
#  'G3:2.5:0.25',
#  'C4:2.75:0.25',
#  'E4:3.0:0.25',
#  'G3:3.25:0.25',
#  'C4:3.5:0.25',
#  'E4:3.75:0.25',
#  'G2:0.0:2.0',
#  'D3:0.25:1.75',
#  'G3:0.5:0.25',
#  'C4:0.75:0.25',
#  'F4:1.0:0.25',
#  'G3:1.25:0.25',
#  'C4:1.5:0.25',
#  'F4:1.75:0.25',
#  'G2:2.0:2.0',
#  'D3:2.25:1.75',
#  'G3:2.5:0.25',
#  'C4:2.75:0.25',
#  'F4:3.0:0.25',
#  'G3:3.25:0.25',
#  'C4:3.5:0.25',
#  'F4:3.75:0.25',
#  'G2:0.0:2.0',
#  'D3:0.25:1.75',
#  'G3:0.5:0.25',
#  'B3:0.75:0.25',
#  'F4:1.0:0.25',
#  'G3:1.25:0.25',
#  'B3:1.5:0.25',
#  'F4:1.75:0.25',
#  'G2:2.0:2.0',
#  'D3:2.25:1.75',
#  'G3:2.5:0.25',
#  'B3:2.75:0.25',
#  'F4:3.0:0.25',
#  'G3:3.25:0.25',
#  'B3:3.5:0.25',
#  'F4:3.75:0.25',
#  'G2:0.0:2.0',
#  'E-3:0.25:1.75',
#  'A3:0.5:0.25',
#  'C4:0.75:0.25',
#  'F#4:1.0:0.25',
#  'A3:1.25:0.25',
#  'C4:1.5:0.25',
#  'F#4:1.75:0.25',
#  'G2:2.0:2.0',
#  'E-3:2.25:1.75',
#  'A3:2.5:0.25',
#  'C4:2.75:0.25',
#  'F#4:3.0:0.25',
#  'A3:3.25:0.25',
#  'C4:3.5:0.25',
#  'F#4:3.75:0.25',
#  'G2:0.0:2.0',
#  'E3:0.25:1.75',
#  'G3:0.5:0.25',
#  'C4:0.75:0.25',
#  'G4:1.0:0.25',
#  'G3:1.25:0.25',
#  'C4:1.5:0.25',
#  'G4:1.75:0.25',
#  'G2:2.0:2.0',
#  'E3:2.25:1.75',
#  'G3:2.5:0.25',
#  'C4:2.75:0.25',
#  'G4:3.0:0.25',
#  'G3:3.25:0.25',
#  'C4:3.5:0.25',
#  'G4:3.75:0.25',
#  'G2:0.0:2.0',
#  'D3:0.25:1.75',
#  'G3:0.5:0.25',
#  'C4:0.75:0.25',
#  'F4:1.0:0.25',
#  'G3:1.25:0.25',
#  'C4:1.5:0.25',
#  'F4:1.75:0.25',
#  'G2:2.0:2.0',
#  'D3:2.25:1.75',
#  'G3:2.5:0.25',
#  'C4:2.75:0.25',
#  'F4:3.0:0.25',
#  'G3:3.25:0.25',
#  'C4:3.5:0.25',
#  'F4:3.75:0.25',
#  'G2:0.0:2.0',
#  'D3:0.25:1.75',
#  'G3:0.5:0.25',
#  'B3:0.75:0.25',
#  'F4:1.0:0.25',
#  'G3:1.25:0.25',
#  'B3:1.5:0.25',
#  'F4:1.75:0.25',
#  'G2:2.0:2.0',
#  'D3:2.25:1.75',
#  'G3:2.5:0.25',
#  'B3:2.75:0.25',
#  'F4:3.0:0.25',
#  'G3:3.25:0.25',
#  'B3:3.5:0.25',
#  'F4:3.75:0.25',
#  'C2:0.0:2.0',
#  'C3:0.25:1.75',
#  'G3:0.5:0.25',
#  'B-3:0.75:0.25',
#  'E4:1.0:0.25',
#  'G3:1.25:0.25',
#  'B-3:1.5:0.25',
#  'E4:1.75:0.25',
#  'C2:2.0:2.0',
#  'C3:2.25:1.75',
#  'G3:2.5:0.25',
#  'B-3:2.75:0.25',
#  'E4:3.0:0.25',
#  'G3:3.25:0.25',
#  'B-3:3.5:0.25',
#  'E4:3.75:0.25',
#  'C2:0.0:4.0',
#  'C3:0.25:3.75',
#  'F3:0.5:0.25',
#  'A3:0.75:0.25',
#  'C4:1.0:0.25',
#  'F4:1.25:0.25',
#  'C4:1.5:0.25',
#  'A3:1.75:0.25',
#  'C4:2.0:0.25',
#  'A3:2.25:0.25',
#  'F3:2.5:0.25',
#  'A3:2.75:0.25',
#  'F3:3.0:0.25',
#  'D3:3.25:0.25',
#  'F3:3.5:0.25',
#  'D3:3.75:0.25',
#  'C2:0.0:4.0',
#  'B2:0.25:3.75',
#  'G4:0.5:0.25',
#  'B4:0.75:0.25',
#  'D5:1.0:0.25',
#  'F5:1.25:0.25',
#  'D5:1.5:0.25',
#  'B4:1.75:0.25',
#  'D5:2.0:0.25',
#  'B4:2.25:0.25',
#  'G4:2.5:0.25',
#  'B4:2.75:0.25',
#  'D4:3.0:0.25',
#  'F4:3.25:0.25',
#  'E4:3.5:0.25',
#  'D4:3.75:0.25',
#  'G4:0.0:1.0',
#  'C5:0.0:1.0',
#  'C3:0.0:1.0',
#  'E4:0.0:1.0',
#  'C2:0.0:4.0',
#  'C5:0.0:0.25',
#  'C3:0.0:0.25',
#  'E-4:0.25:0.25',
#  'G3:0.25:0.25',
#  'D4:0.5:0.25',
#  'F3:0.5:0.25',
#  'E-4:0.75:0.25',
#  'G3:0.75:0.25',
#  'C4:1.0:0.25',
#  'E-3:1.0:0.25',
#  'E-4:1.25:0.25',
#  'G3:1.25:0.25',
#  'D4:1.5:0.25',
#  'F3:1.5:0.25',
#  'E-4:1.75:0.25',
#  'G3:1.75:0.25',
#  'C5:2.0:0.25',
#  'C3:2.0:0.25',
#  'E-4:2.25:0.25',
#  'G3:2.25:0.25',
#  'D4:2.5:0.25',
#  'F3:2.5:0.25',
#  'E-4:2.75:0.25',
#  'G3:2.75:0.25',
#  'C4:3.0:0.25',
#  'E-3:3.0:0.25',
#  'E-4:3.25:0.25',
#  'G3:3.25:0.25',
#  'D4:3.5:0.25',
#  'F3:3.5:0.25',
#  'E-4:3.75:0.25',
#  'G3:3.75:0.25',
#  'G#4:0.0:0.25',
#  'C3:0.0:0.25',
#  'F4:0.25:0.25',
#  'G#3:0.25:0.25',
#  'E4:0.5:0.25',
#  'G3:0.5:0.25',
#  'F4:0.75:0.25',
#  'G#3:0.75:0.25',
#  'D4:1.0:0.25',
#  'F3:1.0:0.25',
#  'F4:1.25:0.25',
#  'G#3:1.25:0.25',
#  'E4:1.5:0.25',
#  'G3:1.5:0.25',
#  'F4:1.75:0.25',
#  'G#3:1.75:0.25',
#  'G#4:2.0:0.25',
#  'C3:2.0:0.25',
#  'F4:2.25:0.25',
#  'G#3:2.25:0.25',
#  'E4:2.5:0.25',
#  'G3:2.5:0.25',
#  'F4:2.75:0.25',
#  'G#3:2.75:0.25',
#  'D4:3.0:0.25',
#  'F3:3.0:0.25',
#  'F4:3.25:0.25',
#  'G#3:3.25:0.25',
#  'E4:3.5:0.25',
#  'G3:3.5:0.25',
#  'F4:3.75:0.25',
#  'G#3:3.75:0.25',
#  'B4:0.0:0.25',
#  'C3:0.0:0.25',
#  'F4:0.25:0.25',
#  'G#3:0.25:0.25',
#  'E-4:0.5:0.25',
#  'G3:0.5:0.25',
#  'F4:0.75:0.25',
#  'G#3:0.75:0.25',
#  'D4:1.0:0.25',
#  'F3:1.0:0.25',
#  'F4:1.25:0.25',
#  'G#3:1.25:0.25',
#  'E-4:1.5:0.25',
#  'G3:1.5:0.25',
#  'F4:1.75:0.25',
#  'G#3:1.75:0.25',
#  'B4:2.0:0.25',
#  'C3:2.0:0.25',
#  'F4:2.25:0.25',
#  'G#3:2.25:0.25',
#  'E-4:2.5:0.25',
#  'G3:2.5:0.25',
#  'F4:2.75:0.25',
#  'G#3:2.75:0.25',
#  'D4:3.0:0.25',
#  'F3:3.0:0.25',
#  'F4:3.25:0.25',
#  'G#3:3.25:0.25',
#  'E-4:3.5:0.25',
#  'G3:3.5:0.25',
#  'F4:3.75:0.25',
#  'G#3:3.75:0.25',
#  'C5:0.0:0.25',
#  'C3:0.0:0.25',
#  'G4:0.25:0.25',
#  'E-3:0.25:0.25',
#  'F4:0.5:0.25',
#  'D3:0.5:0.25',
#  'G4:0.75:0.25',
#  'E-3:0.75:0.25',
#  'E-4:1.0:0.25',
#  'G3:1.0:0.25',
#  'G4:1.25:0.25',
#  'E-3:1.25:0.25',
#  'F4:1.5:0.25',
#  'D3:1.5:0.25',
#  'G4:1.75:0.25',
#  'E-3:1.75:0.25',
#  'C5:2.0:0.25',
#  'C3:2.0:0.25',
#  'G4:2.25:0.25',
#  'E-3:2.25:0.25',
#  'F4:2.5:0.25',
#  'D3:2.5:0.25',
#  'G4:2.75:0.25',
#  'E-3:2.75:0.25',
#  'E-4:3.0:0.25',
#  'G3:3.0:0.25',
#  'G4:3.25:0.25',
#  'E-3:3.25:0.25',
#  'F4:3.5:0.25',
#  'D3:3.5:0.25',
#  'G4:3.75:0.25',
#  'E-3:3.75:0.25',
#  'E-5:0.0:0.25',
#  'C3:0.0:0.25',
#  'G#4:0.25:0.25',
#  'C4:0.25:0.25',
#  'G4:0.5:0.25',
#  'B-3:0.5:0.25',
#  'G#4:0.75:0.25',
#  'C4:0.75:0.25',
#  'E-4:1.0:0.25',
#  'G#3:1.0:0.25',
#  'G#4:1.25:0.25',
#  'C4:1.25:0.25',
#  'G4:1.5:0.25',
#  'B-3:1.5:0.25',
#  'G#4:1.75:0.25',
#  'C4:1.75:0.25',
#  'E-5:2.0:0.25',
#  'C3:2.0:0.25',
#  'G#4:2.25:0.25',
#  'C4:2.25:0.25',
#  'G4:2.5:0.25',
#  'B-3:2.5:0.25',
#  'G#4:2.75:0.25',
#  'C4:2.75:0.25',
#  'E-4:3.0:0.25',
#  'G#3:3.0:0.25',
#  'G#4:3.25:0.25',
#  'C4:3.25:0.25',
#  'G4:3.5:0.25',
#  'B-3:3.5:0.25',
#  'G#4:3.75:0.25',
#  'C4:3.75:0.25',
#  'D5:0.0:0.25',
#  'C3:0.0:0.25',
#  'F#4:0.25:0.25',
#  'A3:0.25:0.25',
#  'E4:0.5:0.25',
#  'G3:0.5:0.25',
#  'F#4:0.75:0.25',
#  'A3:0.75:0.25',
#  'D4:1.0:0.25',
#  'F#3:1.0:0.25',
#  'F#4:1.25:0.25',
#  'A3:1.25:0.25',
#  'E4:1.5:0.25',
#  'G3:1.5:0.25',
#  'F#4:1.75:0.25',
#  'A3:1.75:0.25',
#  'D5:2.0:0.25',
#  'C3:2.0:0.25',
#  'F#4:2.25:0.25',
#  'A3:2.25:0.25',
#  'E4:2.5:0.25',
#  'G3:2.5:0.25',
#  'F#4:2.75:0.25',
#  'A3:2.75:0.25',
#  'D4:3.0:0.25',
#  'F#3:3.0:0.25',
#  'F#4:3.25:0.25',
#  'A3:3.25:0.25',
#  'E4:3.5:0.25',
#  'G3:3.5:0.25',
#  'F#4:3.75:0.25',
#  'A3:3.75:0.25',
#  'D5:0.0:0.25',
#  'B-2:0.0:0.25',
#  'G4:0.25:0.25',
#  'B-3:0.25:0.25',
#  'F#4:0.5:0.25',
#  'A3:0.5:0.25',
#  'G4:0.75:0.25',
#  'B-3:0.75:0.25',
#  'D4:1.0:0.25',
#  'G3:1.0:0.25',
#  'G4:1.25:0.25',
#  'B-3:1.25:0.25',
#  'F#4:1.5:0.25',
#  'A3:1.5:0.25',
#  'G4:1.75:0.25',
#  'B-3:1.75:0.25',
#  'D5:2.0:0.25',
#  'B-2:2.0:0.25',
#  'G4:2.25:0.25',
#  'B-3:2.25:0.25',
#  'F#4:2.5:0.25',
#  'A3:2.5:0.25',
#  'G4:2.75:0.25',
#  'B-3:2.75:0.25',
#  'D4:3.0:0.25',
#  'G3:3.0:0.25',
#  'G4:3.25:0.25',
#  'B-3:3.25:0.25',
#  'F#4:3.5:0.25',
#  'A3:3.5:0.25',
#  'G4:3.75:0.25',
#  'B-3:3.75:0.25',
#  'C5:0.0:0.25',
#  'B-2:0.0:0.25',
#  'E4:0.25:0.25',
#  'G3:0.25:0.25',
#  'D4:0.5:0.25',
#  'F3:0.5:0.25',
#  'E4:0.75:0.25',
#  'G3:0.75:0.25',
#  'C4:1.0:0.25',
#  'E3:1.0:0.25',
#  'E4:1.25:0.25',
#  'G3:1.25:0.25',
#  'D4:1.5:0.25',
#  'F3:1.5:0.25',
#  'E4:1.75:0.25',
#  'G3:1.75:0.25',
#  'C5:2.0:0.25',
#  'B-2:2.0:0.25',
#  'E4:2.25:0.25',
#  'G3:2.25:0.25',
#  'D4:2.5:0.25',
#  'F3:2.5:0.25',
#  'E4:2.75:0.25',
#  'G3:2.75:0.25',
#  'C4:3.0:0.25',
#  'E3:3.0:0.25',
#  'E4:3.25:0.25',
#  'G3:3.25:0.25',
#  'D4:3.5:0.25',
#  'F3:3.5:0.25',
#  'E4:3.75:0.25',
#  'G3:3.75:0.25',
#  'C5:0.0:0.25',
#  'G#2:0.0:0.25',
#  'F4:0.25:0.25',
#  'G#3:0.25:0.25',
#  'E4:0.5:0.25',
#  'G3:0.5:0.25',
#  'F4:0.75:0.25',
#  'G#3:0.75:0.25',
#  'C4:1.0:0.25',
#  'F3:1.0:0.25',
#  'F4:1.25:0.25',
#  'G#3:1.25:0.25',
#  'E4:1.5:0.25',
#  'G3:1.5:0.25',
#  'F4:1.75:0.25',
#  'G#3:1.75:0.25',
#  'C5:2.0:0.25',
#  'G#2:2.0:0.25',
#  'F4:2.25:0.25',
#  'G#3:2.25:0.25',
#  'E4:2.5:0.25',
#  'G3:2.5:0.25',
#  'F4:2.75:0.25',
#  'G#3:2.75:0.25',
#  'C4:3.0:0.25',
#  'F3:3.0:0.25',
#  'F4:3.25:0.25',
#  'G#3:3.25:0.25',
#  'E4:3.5:0.25',
#  'G3:3.5:0.25',
#  'F4:3.75:0.25',
#  'G#3:3.75:0.25',
#  'B-4:0.0:0.25',
#  'G#2:0.0:0.25',
#  'F4:0.25:0.25',
#  'D3:0.25:0.25',
#  'E-4:0.5:0.25',
#  'C3:0.5:0.25',
#  'F4:0.75:0.25',
#  'D3:0.75:0.25',
#  'D4:1.0:0.25',
#  'F3:1.0:0.25',
#  'F4:1.25:0.25',
#  'D3:1.25:0.25',
#  'E-4:1.5:0.25',
#  'C3:1.5:0.25',
#  'F4:1.75:0.25',
#  'D3:1.75:0.25',
#  'B-4:2.0:0.25',
#  'G#2:2.0:0.25',
#  'F4:2.25:0.25',
#  'D3:2.25:0.25',
#  'E-4:2.5:0.25',
#  'C3:2.5:0.25',
#  'F4:2.75:0.25',
#  'D3:2.75:0.25',
#  'D4:3.0:0.25',
#  'F3:3.0:0.25',
#  'F4:3.25:0.25',
#  'D3:3.25:0.25',
#  'E-4:3.5:0.25',
#  'C3:3.5:0.25',
#  'F4:3.75:0.25',
#  'D3:3.75:0.25',
#  'B-4:0.0:0.25',
#  'G2:0.0:0.25',
#  'G4:0.25:0.25',
#  'E-3:0.25:0.25',
#  'F4:0.5:0.25',
#  'D3:0.5:0.25',
#  'G4:0.75:0.25',
#  'E-3:0.75:0.25',
#  'E-4:1.0:0.25',
#  'G3:1.0:0.25',
#  'G4:1.25:0.25',
#  'E-3:1.25:0.25',
#  'F4:1.5:0.25',
#  'D3:1.5:0.25',
#  'G4:1.75:0.25',
#  'E-3:1.75:0.25',
#  'B-4:2.0:0.25',
#  'G2:2.0:0.25',
#  'G4:2.25:0.25',
#  'E-3:2.25:0.25',
#  'F4:2.5:0.25',
#  'D3:2.5:0.25',
#  'G4:2.75:0.25',
#  'E-3:2.75:0.25',
#  'E-4:3.0:0.25',
#  'G3:3.0:0.25',
#  'G4:3.25:0.25',
#  'E-3:3.25:0.25',
#  'F4:3.5:0.25',
#  'D3:3.5:0.25',
#  'G4:3.75:0.25',
#  'E-3:3.75:0.25',
#  'G#4:0.0:0.25',
#  'C3:0.0:0.25',
#  'G4:0.25:0.25',
#  'E-3:0.25:0.25',
#  'F4:0.5:0.25',
#  'D3:0.5:0.25',
#  'G4:0.75:0.25',
#  'E-3:0.75:0.25',
#  'E-4:1.0:0.25',
#  'G#3:1.0:0.25',
#  'G4:1.25:0.25',
#  'E-3:1.25:0.25',
#  'F4:1.5:0.25',
#  'D3:1.5:0.25',
#  'G4:1.75:0.25',
#  'E-3:1.75:0.25',
#  'G#4:2.0:0.25',
#  'C3:2.0:0.25',
#  'G4:2.25:0.25',
#  'E-3:2.25:0.25',
#  'F4:2.5:0.25',
#  'D3:2.5:0.25',
#  'G4:2.75:0.25',
#  'E-3:2.75:0.25',
#  'E-4:3.0:0.25',
#  'G#3:3.0:0.25',
#  'G4:3.25:0.25',
#  'E-3:3.25:0.25',
#  'F4:3.5:0.25',
#  'D3:3.5:0.25',
#  'G4:3.75:0.25',
#  'E-3:3.75:0.25',
#  'G#4:0.0:0.25',
#  'D3:0.0:0.25',
#  'D4:0.25:0.25',
#  'F3:0.25:0.25',
#  'C4:0.5:0.25',
#  'E-3:0.5:0.25',
#  'D4:0.75:0.25',
#  'F3:0.75:0.25',
#  'B-3:1.0:0.25',
#  'G#3:1.0:0.25',
#  'D4:1.25:0.25',
#  'F3:1.25:0.25',
#  'C4:1.5:0.25',
#  'E-3:1.5:0.25',
#  'D4:1.75:0.25',
#  'F3:1.75:0.25',
#  'G#4:2.0:0.25',
#  'D3:2.0:0.25',
#  'D4:2.25:0.25',
#  'F3:2.25:0.25',
#  'C4:2.5:0.25',
#  'E-3:2.5:0.25',
#  'D4:2.75:0.25',
#  'F3:2.75:0.25',
#  'B-3:3.0:0.25',
#  'G#3:3.0:0.25',
#  'D4:3.25:0.25',
#  'F3:3.25:0.25',
#  'C4:3.5:0.25',
#  'E-3:3.5:0.25',
#  'D4:3.75:0.25',
#  'F3:3.75:0.25',
#  'G4:0.0:0.25',
#  'E-3:0.0:0.25',
#  'B-3:0.25:0.25',
#  'G3:0.25:0.25',
#  'G#3:0.5:0.25',
#  'F3:0.5:0.25',
#  'B-3:0.75:0.25',
#  'G3:0.75:0.25',
#  'E-4:1.0:0.25',
#  'G#3:1.0:0.25',
#  'B-3:1.25:0.25',
#  'G3:1.25:0.25',
#  'G#3:1.5:0.25',
#  'F3:1.5:0.25',
#  'B-3:1.75:0.25',
#  'G3:1.75:0.25',
#  'G4:2.0:0.25',
#  'E-3:2.0:0.25',
#  'B-3:2.25:0.25',
#  'G3:2.25:0.25',
#  'G#3:2.5:0.25',
#  'F3:2.5:0.25',
#  'B-3:2.75:0.25',
#  'G3:2.75:0.25',
#  'E-4:3.0:0.25',
#  'G#3:3.0:0.25',
#  'B-3:3.25:0.25',
#  'G3:3.25:0.25',
#  'G#3:3.5:0.25',
#  'F3:3.5:0.25',
#  'B-3:3.75:0.25',
#  'G3:3.75:0.25',
#  'F4:0.0:0.25',
#  'E-3:0.0:0.25',
#  'C4:0.25:0.25',
#  ...]

# %% [markdown]
# # Modeling
